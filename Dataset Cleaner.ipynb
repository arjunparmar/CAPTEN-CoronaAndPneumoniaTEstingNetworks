# %%
import numpy as np
import cv2
import pandas as pd

# %%
data=pd.read_csv("/home/paa/IEEE COVID19/metadata.csv")

# %%
data.head()
# Out:
#    patientid offset sex age   finding survival intubated intubation_present  \
# 0          2      0   M  65  COVID-19        Y       NaN                NaN
# 1          2      3   M  65  COVID-19        Y       NaN                NaN
# 2          2      5   M  65  COVID-19        Y       NaN                NaN
# 3          2      6   M  65  COVID-19        Y       NaN                NaN
# 4          4      0   F  52  COVID-19      NaN       NaN                NaN
#
#   went_icu in_icu  ...              date  \
# 0      NaN    NaN  ...  January 22, 2020
# 1      NaN    NaN  ...  January 25, 2020
# 2      NaN    NaN  ...  January 27, 2020
# 3      NaN    NaN  ...  January 28, 2020
# 4      NaN    NaN  ...  January 25, 2020
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 2        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# ...

# %%
data_array=np.asarray(data)
print(data_array[0][4])
print(data_array[0][-7])
print(len(data_array))
# Out:
# COVID-19
# auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# 682

# %%
j=0
image_name=np.array(len(data_array))
for i in range(0,len(data_array)-1):
    if(data_array[i][4]=="COVID-19"):
        image=data_array[i][-7]
        img=(cv2.imread("/home/paa/IEEE COVID19/images/"+str(image)))
        cv2.imwrite("/home/paa/IEEE COVID19/COVID/"+str(j)+".jpeg",img)
        print("image number:"+str(j)+" is written")
        j=j+1
# Out:
# image number:0 is written
# image number:1 is written
# image number:2 is written
# image number:3 is written
# image number:4 is written
# image number:5 is written
# image number:6 is written
# image number:7 is written
# image number:8 is written
# image number:9 is written
# image number:10 is written
# image number:11 is written
# image number:12 is written
# image number:13 is written
# image number:14 is written
# image number:15 is written
# image number:16 is written
# image number:17 is written
# image number:18 is written
# image number:19 is written
# image number:20 is written
# image number:21 is written
# image number:22 is written
# image number:23 is written
# image number:24 is written
# image number:25 is written
# image number:26 is written
# image number:27 is written
# image number:28 is written
# image number:29 is written
# image number:30 is written
# image number:31 is written
# image number:32 is written
# image number:33 is written
# ...
